# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random

# %%
coordinates = []
triangle = [[50, 50], [500, 950], [950, 50]]
coordinates.extend(triangle)
x, y = random.randint(0,1000), random.randint(0,1000)
coordinates.append([x, y])
coordinates
for i in range(1000000):
  A = random.randint(0,2)
  x, y = 0.5*(x + triangle[A][0]), 0.5*(y + triangle[A][1])
  coordinates.append([x, y])
coord_X = [i[0] for i in coordinates]
coord_Y = [i[1] for i in coordinates]
tabl = pd.DataFrame({'X': coord_X, 'Y': coord_Y})
tabl
# Out:
#                   X           Y
# 0         50.000000   50.000000
# 1        500.000000  950.000000
# 2        950.000000   50.000000
# 3        296.000000  570.000000
# 4        623.000000  310.000000
# ...             ...         ...
# 999999   398.792400  504.539694
# 1000000  224.396200  277.269847
# 1000001  137.198100  163.634924
# 1000002  318.599050  556.817462
# 1000003  184.299525  303.408731
#
# [1000004 rows x 2 columns]

# %%
from matplotlib import figure
plt.style.use('dark_background')
plt.figure(figsize=(30, 14))
plt.scatter(coord_X, coord_Y, c='aqua', s=1)
plt.show()

# %%
type(np.random.randint(0,1000))
# Out:
# int

# %%
type(random.randint(0,1000))
# Out:
# int
